# %%
import yfinance as yf #uses yahoo finance API to get daily stock and index prices

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
# 2024-04-04 00:00:00-04:00  5244.049805  5256.589844  5146.060059  5147.209961
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-03-21 00:00:00-04:00', '2024-03-22 00:00:00-04:00',
#                '2024-03-25 00:00:00-04:00', '2024-03-26 00:00:00-04:00',
#                '2024-03-27 00:00:00-04:00', '2024-03-28 00:00:00-04:00',
#                '2024-04-01 00:00:00-04:00', '2024-04-02 00:00:00-04:00',
#                '2024-04-03 00:00:00-04:00', '2024-04-04 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24180, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#All zeros in both columns
del sp500['Dividends']
del sp500['Stock Splits']

# %%
#Target variable = stock value going up or down

#Price of tomorrow is price of close shifted one day
sp500['Tomorrow'] = sp500['Close'].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
# 2024-04-04 00:00:00-04:00  5244.049805  5256.589844  5146.060059  5147.209961
#
# ...

# %%
sp500['Target'] = (sp500['Tomorrow'] > sp500['Close']).astype(int)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
# 2024-04-04 00:00:00-04:00  5244.049805  5256.589844  5146.060059  5147.209961
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy() #Use more recent stock information
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
# 2024-04-04 00:00:00-04:00  5244.049805  5256.589844  5146.060059  5147.209961
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, min_samples_split = 100, random_state = 1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ['Close', 'Volume', 'Open', 'High', 'Low']
model.fit(train[predictors], train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd 

preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2023-11-09 00:00:00-05:00    1
# 2023-11-10 00:00:00-05:00    1
# 2023-11-13 00:00:00-05:00    0
# 2023-11-14 00:00:00-05:00    0
# 2023-11-15 00:00:00-05:00    0
#                             ..
# 2024-03-28 00:00:00-04:00    0
# 2024-04-01 00:00:00-04:00    0
# 2024-04-02 00:00:00-04:00    0
# 2024-04-03 00:00:00-04:00    0
# 2024-04-04 00:00:00-04:00    0
# Length: 100, dtype: int64

# %%
precision_score(test['Target'], preds)
# Out:
# 0.6666666666666666

# %%
combined = pd.concat([test['Target'], preds], axis=1)
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train['Target'])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name='Predictions')
    combined = pd.concat([test['Target'], preds], axis=1)
    return combined

# %%
#implement backtesting
#start of 2500 (250 days/year in dataset over 10 years)
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# 0    3534
# 1    2596
# Name: Predictions, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5288906009244992

# %%
predictions['Target'].value_counts()/predictions.shape[0]
# Out:
# 1    0.534584
# 0    0.465416
# Name: Target, dtype: float64

# %%
intervals = [2, 5, 60, 250, 1000] #Calculate rolling averages across these day intervals
new_predictors = []

for interval in intervals:
    rolling_averages = sp500.rolling(interval).mean()
    ratio_column = f"Close_Ratio_{interval}"
    trend_column = f"Trend_{interval}"
    sp500[ratio_column] = sp500['Close']/rolling_averages['Close']
    sp500[trend_column] = sp500.shift(1).rolling(interval).sum()['Target'] #rolling sum of target
    new_predictors+=[ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
# 2024-04-04 00:00:00-04:00  5244.049805  5256.589844  5146.060059  5147.209961
#
# ...

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-03-27 00:00:00-04:00  5226.310059  5249.259766  5213.919922  5248.490234
# 2024-03-28 00:00:00-04:00  5248.029785  5264.850098  5245.819824  5254.350098
# 2024-04-01 00:00:00-04:00  5257.970215  5263.950195  5229.200195  5243.770020
# 2024-04-02 00:00:00-04:00  5204.290039  5208.339844  5184.049805  5205.810059
# 2024-04-03 00:00:00-04:00  5194.370117  5228.750000  5194.370117  5211.490234
#
# ...

# %%
model = RandomForestClassifier(n_estimators = 200, min_samples_split = 50, random_state = 1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train['Target'])
    preds = model.predict_proba(test[predictors])[:,1] #probability stock price will go up or down
    preds[preds >= .6] = 1 #model should be over 60% confident stock price will go up
    preds[preds <= .6] = 0
    preds = pd.Series(preds, index=test.index, name='Predictions')
    combined = pd.concat([test['Target'], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# 0.0    4297
# 1.0     832
# Name: Predictions, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.5733173076923077

# %%
#Stock went up 53% of days, stock goes up on 57% of days that the model says to buy
#Model has predictive power --> success!

# %%
#Future -- look at indices from around the world that open before S&P500, add in news article info
